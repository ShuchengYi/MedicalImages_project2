# %%
import sys
import os
from pathlib import Path

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(project_root)

GNDTRUTH = Path('../data/raw/COMMON_images_masks/')
RAWIMGS = Path('../data/raw/GROUP_images/')
DATA = (RAWIMGS.parent).parent
MASKS = DATA/'masks'

import SimpleITK as sitk
from utils import *
from linear_registration import register_linear

# %%
mov_names = ['g1_54', 'g1_55', 'g1_56']
fix_name = 'common_40'

fix_im = sitk.ReadImage(GNDTRUTH/(fix_name+'_image.nii.gz'))
mov_ims = [sitk.ReadImage(RAWIMGS/(name+'_image.nii.gz')) for name in mov_names]
fix_msk = sitk.ReadImage(MASKS/(fix_name+'_regmask.nii.gz'))
mov_msks = [sitk.ReadImage(MASKS/(name+'_mask.nii.gz')) for name in mov_names]

# Arrays from images
fix_im_data = sitk.GetArrayFromImage(fix_im)
fix_msk_data = sitk.GetArrayFromImage(fix_msk)
mov_ims_data = [sitk.GetArrayFromImage(img) for img in mov_ims]
mov_msks_data = [sitk.GetArrayFromImage(msk) for msk in mov_msks]

# %%
registrations = []
for idx, (mov_im, mov_msk) in enumerate(zip(mov_ims, mov_msks)):
    print(f'---- Image {idx} ----')
    registrations.append(register_linear(fix_im, mov_im, fix_mask=None, mov_mask=mov_msk, verbose=True))
# Out:
# ---- Image 0 ----
# Creating bone mask for fixed image...
# Generating mask from HU thresholding with HU_min=185, HU_max=500...
# Mask generated!
# Cropping fixed image to ROI...
# Cropping moving image to ROI...
# Estimating affine transformation...
# itk::simple::CompositeTransform
#  CompositeTransform (0x2d79e3e0)
#    RTTI typeinfo:   itk::CompositeTransform<double, 3u>
#    Reference Count: 1
#    Modified Time: 7239864
#    Debug: Off
#    Object Name:
#    Observers:
#      none
#    TransformQueue:
#    >>>>>>>>>
#    AffineTransform (0x2ee991e0)
#      RTTI typeinfo:   itk::AffineTransform<double, 3u>
#      Reference Count: 1
#      Modified Time: 7239710
#      Debug: Off
#      Object Name:
#      Observers:
#        none
#      Matrix:
#        0.985825 0.0279998 -0.0528489
#        0.0784387 0.974097 -0.00591919
#        -0.07782 0.100621 0.944333
#      Offset: [19.6883, 12.4586, -1536.83]
#      Center: [-79.3516, -127.672, 842.698]
#      Translation: [-27.2974, 4.55335, -1590.41]
#      Inverse:
#        1.02168 -0.0352509 0.0569566
#        -0.0817057 1.02875 0.0018757
#        0.0928998 -0.11252 1.06344
#      Singular: 0
#    TransformsToOptimizeFlags:
#            1
#    TransformsToOptimizeQueue:
#    PreviousTransformsToOptimizeUpdateTime: 0
#
# --------
# Optimizer stop condition: GradientDescentOptimizerv4Template: Convergence checker passed at iteration 183.
# Number of iterations: 183
# --------
# Applying affine transformation...
# Linear registration finished.
# ---- Image 1 ----
# Creating bone mask for fixed image...
# Generating mask from HU thresholding with HU_min=185, HU_max=500...
# Mask generated!
# Cropping fixed image to ROI...
# Cropping moving image to ROI...
# Estimating affine transformation...
# itk::simple::CompositeTransform
#  CompositeTransform (0x2f6efc90)
#    RTTI typeinfo:   itk::CompositeTransform<double, 3u>
#    Reference Count: 1
#    Modified Time: 7854395
#    Debug: Off
#    Object Name:
#    Observers:
#      none
#    TransformQueue:
#    >>>>>>>>>
#    AffineTransform (0x2f85cb90)
#      RTTI typeinfo:   itk::AffineTransform<double, 3u>
#      Reference Count: 1
#      Modified Time: 7854241
#      Debug: Off
#      Object Name:
#      Observers:
#        none
#      Matrix:
#        1.03398 0.0207505 -0.07228
#        0.0206319 0.997519 0.00980918
#        0.00128004 0.0101912 1.00754
#      Offset: [41.0886, -4.98467, -1621.98]
#      Center: [-79.3516, -127.672, 842.698]
#      Translation: [-25.1669, 1.96115, -1617.03]
#      Inverse:
#        0.967471 -0.0208366 0.0696084
#        -0.0200003 1.00302 -0.0112
#        -0.00102684 -0.010119 0.992542
#      Singular: 0
#    TransformsToOptimizeFlags:
#            1
#    TransformsToOptimizeQueue:
#    PreviousTransformsToOptimizeUpdateTime: 0
#
# --------
# Optimizer stop condition: GradientDescentOptimizerv4Template: Convergence checker passed at iteration 52.
# Number of iterations: 52
# --------
# Applying affine transformation...
# Linear registration finished.
# ---- Image 2 ----
# Creating bone mask for fixed image...
# Generating mask from HU thresholding with HU_min=185, HU_max=500...
# Mask generated!
# Cropping fixed image to ROI...
# Cropping moving image to ROI...
# Estimating affine transformation...
# itk::simple::CompositeTransform
#  CompositeTransform (0x2f0642b0)
#    RTTI typeinfo:   itk::CompositeTransform<double, 3u>
#    Reference Count: 1
#    Modified Time: 8473402
#    Debug: Off
#    Object Name:
#    Observers:
#      none
#    TransformQueue:
#    >>>>>>>>>
#    AffineTransform (0x31822910)
#      RTTI typeinfo:   itk::AffineTransform<double, 3u>
#      Reference Count: 1
#      Modified Time: 8473248
#      Debug: Off
#      Object Name:
#      Observers:
#        none
#      Matrix:
#        1.04347 0.059314 -0.0484755
#        -0.0932628 0.877794 0.0530449
#        0.0224799 -0.0470211 0.9132
#      Offset: [73.9898, 248.014, -1455.5]
#      Center: [-79.3516, -127.672, 842.698]
#      Translation: [22.1174, 315.718, -1524.43]
#      Inverse:
#        0.951687 -0.0614098 0.0540856
#        0.102211 1.12909 -0.0601595
#        -0.0181644 0.0596491 1.09062
#      Singular: 0
#    TransformsToOptimizeFlags:
#            1
#    TransformsToOptimizeQueue:
#    PreviousTransformsToOptimizeUpdateTime: 0
#
# --------
# Optimizer stop condition: GradientDescentOptimizerv4Template: Convergence checker passed at iteration 134.
# Number of iterations: 134
# --------
# Applying affine transformation...
# Linear registration finished.

# %%
mov_ims_reg = [reg['registered_image'] for reg in registrations]
mov_msks_reg = [reg['registered_mask'] for reg in registrations]
lin_tfms = [reg['affine_tfm'] for reg in registrations]

# %%
mov_ims_reg_data = [sitk.GetArrayFromImage(im) for im in mov_ims_reg]
mov_msks_reg_data = [sitk.GetArrayFromImage(im) for im in mov_msks_reg]

# %%
show_interactive_overlay(fix_im_data, mov_ims_reg_data[0], 'axial')
# Out:
# interactive(children=(IntSlider(value=143, description='slc', max=285), Output()), _dom_classes=('widget-inter…
# <function utils.visualization.show_axial_overlay(fix_arr, mov_arr, slc)>

# %%
# Change folder to 'with_regmask' if the fix_mask is provided in the registration. Otherwise use folder 'with_HUmask'
for idx, name in enumerate(mov_names):
    sitk.WriteImage(mov_ims_reg[idx], DATA/('linear_registrations/with_HUmask/'+name+'_linreg_'+fix_name+'_img.nii.gz'))
    sitk.WriteImage(mov_msks_reg[idx], DATA/('linear_registrations/with_HUmask/'+name+'_linreg_'+fix_name+'_msk.nii.gz'))
    sitk.WriteTransform(lin_tfms[idx], DATA/('linear_registrations/with_HUmask/transforms/'+name+'_linreg_'+fix_name+'.tfm'))

# %%
fix_im2 = sitk.ReadImage(GNDTRUTH/'common_41_image.nii.gz')
fix_im3 = sitk.ReadImage(GNDTRUTH/'common_42_image.nii.gz')
fix_im2_data = sitk.GetArrayFromImage(fix_im2)
fix_im3 = sitk.rea
